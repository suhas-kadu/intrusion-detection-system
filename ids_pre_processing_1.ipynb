# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("./UNSW-NB15_1.csv", low_memory=False)
df2 = pd.read_csv("./UNSW-NB15_2.csv", low_memory=False)
df3 = pd.read_csv("./UNSW-NB15_3.csv")
df4 = pd.read_csv("./UNSW-NB15_4.csv")

# %%
df1.head()
# Out:
#          srcip  sport          dstip dsport proto state       dur  sbytes  \
# 0  ﻿59.166.0.0   1390  149.171.126.6     53   udp   CON  0.001055     132
# 1   59.166.0.0  33661  149.171.126.9   1024   udp   CON  0.036133     528
# 2   59.166.0.6   1464  149.171.126.7     53   udp   CON  0.001119     146
# 3   59.166.0.5   3593  149.171.126.5     53   udp   CON  0.001209     132
# 4   59.166.0.3  49664  149.171.126.0     53   udp   CON  0.001169     146
#
#    dbytes  sttl  ...  ct_ftp_cmd  ct_srv_src  ct_srv_dst ct_dst_ltm  \
# 0     164    31  ...           0           3           7          1
# 1     304    31  ...           0           2           4          2
# 2     178    31  ...           0          12           8          1
# 3     164    31  ...           0           6           9          1
# 4     178    31  ...           0           7           9          1
#
#    ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# ...

# %%
df2.head()
# Out:
#         srcip  sport          dstip dsport proto state       dur  sbytes  \
# 0  59.166.0.0   7832  149.171.126.3   5607   tcp   FIN  0.144951    5174
# 1  59.166.0.8  11397  149.171.126.6     21   tcp   FIN  0.116107    2934
# 2  59.166.0.0   3804  149.171.126.3     53   udp   CON  0.000986     146
# 3  59.166.0.8  14339  149.171.126.6  14724   tcp   FIN  0.038480    8928
# 4  59.166.0.8  39094  149.171.126.3     53   udp   CON  0.001026     130
#
#    dbytes  sttl  ...  ct_ftp_cmd  ct_srv_src  ct_srv_dst ct_dst_ltm  \
# 0   91072    31  ...           0          13          13          6
# 1    3742    31  ...           1           1           2          7
# 2     178    31  ...           0          13          13          6
# 3     320    31  ...           0           8          20          7
# 4     162    31  ...           0           8          13          6
#
#    ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# ...

# %%
df3.head()
# Out:
#             srcip  sport          dstip dsport proto state       dur  sbytes  \
# 0      59.166.0.3  54771  149.171.126.2  27709   tcp   FIN  0.650574    8928
# 1      59.166.0.8  13289  149.171.126.9   5190   tcp   FIN  0.007980    2158
# 2  149.171.126.18   1043   175.45.176.3     53   udp   INT  0.000005     264
# 3  149.171.126.18   1043   175.45.176.3     53   udp   INT  0.000005     264
# 4      59.166.0.3  10275  149.171.126.0     25   tcp   FIN  0.486578   37462
#
#    dbytes  sttl  ...  ct_ftp_cmd  ct_srv_src  ct_srv_dst ct_dst_ltm  \
# 0     320    31  ...                       3           5          2
# 1    2464    31  ...                       3           5          1
# 2       0    60  ...                      19          19         19
# 3       0    60  ...                      19          19         19
# 4    3380    31  ...                       3           2          3
#
#    ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# ...

# %%
df4.head()
# Out:
#         srcip  sport          dstip dsport proto state       dur  sbytes  \
# 0  59.166.0.9   9685  149.171.126.2     80   tcp   FIN  5.864748   19410
# 1  59.166.0.2   1421  149.171.126.4     53   udp   CON  0.001391     146
# 2  59.166.0.2  21553  149.171.126.2     25   tcp   FIN  0.053948   37812
# 3  59.166.0.8  45212  149.171.126.4     53   udp   CON  0.000953     146
# 4  59.166.0.0  59922  149.171.126.8   6881   tcp   FIN  8.633186   25056
#
#     dbytes  sttl  ...  ct_ftp_cmd  ct_srv_src  ct_srv_dst ct_dst_ltm  \
# 0  1087890    31  ...                       3           1          4
# 1      178    31  ...                       3           5          2
# 2     3380    31  ...                       1           1          4
# 3      178    31  ...                       2           5          2
# 4  1094788    31  ...                       9           7          2
#
#    ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# ...

# %%
df1.shape
# Out:
# (65535, 49)

# %%
df1.tail()
# Out:
#             srcip  sport          dstip dsport proto state       dur  sbytes  \
# 65530  59.166.0.6  45941  149.171.126.9     25   tcp   FIN  0.522265   37232
# 65531  59.166.0.9  35335  149.171.126.5  29722   tcp   FIN  0.040876    4222
# 65532  59.166.0.4   5485  149.171.126.7    143   tcp   FIN  0.039446    7820
# 65533  59.166.0.7  32073  149.171.126.9     25   tcp   FIN  0.488009   37502
# 65534  59.166.0.5   3295  149.171.126.0     53   udp   CON  0.001121     146
#
#        dbytes  sttl  ...  ct_ftp_cmd  ct_srv_src  ct_srv_dst ct_dst_ltm  \
# 65530    3276    31  ...           0           1           1          2
# 65531   64070    31  ...           0           3           9          1
# 65532   15306    31  ...           0           6           2          2
# 65533    3380    31  ...           0           1           2          1
# 65534     178    31  ...           0           2           4          1
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 49 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   srcip             65535 non-null  object
#  1   sport             65535 non-null  object
#  2   dstip             65535 non-null  object
#  3   dsport            65535 non-null  object
#  4   proto             65535 non-null  object
#  5   state             65535 non-null  object
#  6   dur               65535 non-null  float64
#  7   sbytes            65535 non-null  int64
#  8   dbytes            65535 non-null  int64
#  9   sttl              65535 non-null  int64
#  10  dttl              65535 non-null  int64
#  11  sloss             65535 non-null  int64
#  12  dloss             65535 non-null  int64
#  13  service           65535 non-null  object
#  14  Sload             65535 non-null  float64
#  15  Dload             65535 non-null  float64
# ...

# %%
df1.describe()
# Out:
#                 dur        sbytes        dbytes          sttl          dttl  \
# count  65535.000000  6.553500e+04  6.553500e+04  65535.000000  65535.000000
# mean       1.004599  5.622007e+03  4.226032e+04     49.663966     44.401709
# std        4.673287  6.684375e+04  1.801440e+05     61.337842     58.134280
# min        0.000000  2.800000e+01  0.000000e+00      0.000000      0.000000
# 25%        0.004388  5.020000e+02  3.040000e+02     31.000000     29.000000
# 50%        0.037005  1.684000e+03  2.456000e+03     31.000000     29.000000
# 75%        0.483564  3.806000e+03  1.454000e+04     31.000000     29.000000
# max       59.999527  7.219804e+06  1.465542e+07    255.000000    254.000000
#
#               sloss         dloss         Sload         Dload         Spkts  \
# count  65535.000000  65535.000000  6.553500e+04  6.553500e+04  65535.000000
# mean       6.173251     18.814221  7.011366e+06  2.536167e+06     38.220920
# ...

# %%
df1.corr()
# Out:
# <ipython-input-14-49b3fcfeb4d1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#                        dur    sbytes    dbytes      sttl      dttl     sloss  \
# dur               1.000000  0.138576  0.266877  0.027360  0.035554  0.173733
# sbytes            0.138576  1.000000  0.035701  0.016146  0.073789  0.958682
# dbytes            0.266877  0.035701  1.000000 -0.064834 -0.029517  0.084028
# sttl              0.027360  0.016146 -0.064834  1.000000  0.672026 -0.008396
# dttl              0.035554  0.073789 -0.029517  0.672026  1.000000  0.061898
# sloss             0.173733  0.958682  0.084028 -0.008396  0.061898  1.000000
# dloss             0.265910  0.037647  0.993181 -0.077920 -0.035022  0.109988
# Sload            -0.016459 -0.003516 -0.017457  0.217283 -0.053893 -0.014722
# ...

# %%
df1.dtypes
# Out:
# srcip                object
# sport                object
# dstip                object
# dsport               object
# proto                object
# state                object
# dur                 float64
# sbytes                int64
# dbytes                int64
# sttl                  int64
# dttl                  int64
# sloss                 int64
# dloss                 int64
# service              object
# Sload               float64
# Dload               float64
# Spkts                 int64
# Dpkts                 int64
# swin                  int64
# dwin                  int64
# stcpb                 int64
# dtcpb                 int64
# smeansz               int64
# dmeansz               int64
# trans_depth           int64
# res_bdy_len           int64
# Sjit                float64
# Djit                float64
# Stime                 int64
# Ltime                 int64
# Sintpkt             float64
# Dintpkt             float64
# tcprtt              float64
# ...

# %%
df1.isnull().sum()
# Out:
# srcip                   0
# sport                   0
# dstip                   0
# dsport                  0
# proto                   0
# state                   0
# dur                     0
# sbytes                  0
# dbytes                  0
# sttl                    0
# dttl                    0
# sloss                   0
# dloss                   0
# service                 0
# Sload                   0
# Dload                   0
# Spkts                   0
# Dpkts                   0
# swin                    0
# dwin                    0
# stcpb                   0
# dtcpb                   0
# smeansz                 0
# dmeansz                 0
# trans_depth             0
# res_bdy_len             0
# Sjit                    0
# Djit                    0
# Stime                   0
# Ltime                   0
# Sintpkt                 0
# Dintpkt                 0
# tcprtt                  0
# synack                  0
# ackdat                  0
# ...

# %%
df1.isna().sum()
# Out:
# srcip                   0
# sport                   0
# dstip                   0
# dsport                  0
# proto                   0
# state                   0
# dur                     0
# sbytes                  0
# dbytes                  0
# sttl                    0
# dttl                    0
# sloss                   0
# dloss                   0
# service                 0
# Sload                   0
# Dload                   0
# Spkts                   0
# Dpkts                   0
# swin                    0
# dwin                    0
# stcpb                   0
# dtcpb                   0
# smeansz                 0
# dmeansz                 0
# trans_depth             0
# res_bdy_len             0
# Sjit                    0
# Djit                    0
# Stime                   0
# Ltime                   0
# Sintpkt                 0
# Dintpkt                 0
# tcprtt                  0
# synack                  0
# ackdat                  0
# ...

# %% [markdown]
# ## Handling Missing Values

# %% [markdown]
# ### 1. Dropping the rows or columns

# %%
# As ct_flw_http_mthd, is_ftp_login columns have very very less correlation with final result they can be dropped 

df_1 = df1
df_1 = df_1.drop(['ct_flw_http_mthd','is_ftp_login' ], axis = 1)

# %%
df_1.shape
# Out:
# (65535, 47)

# %%
## Droppiing the rows having missing values 
df_1 = df_1.dropna()

# %%
df_1.shape
# Out:
# (4695, 47)

# %%
df1.isna().sum()
# Out:
# srcip                   0
# sport                   0
# dstip                   0
# dsport                  0
# proto                   0
# state                   0
# dur                     0
# sbytes                  0
# dbytes                  0
# sttl                    0
# dttl                    0
# sloss                   0
# dloss                   0
# service                 0
# Sload                   0
# Dload                   0
# Spkts                   0
# Dpkts                   0
# swin                    0
# dwin                    0
# stcpb                   0
# dtcpb                   0
# smeansz                 0
# dmeansz                 0
# trans_depth             0
# res_bdy_len             0
# Sjit                    0
# Djit                    0
# Stime                   0
# Ltime                   0
# Sintpkt                 0
# Dintpkt                 0
# tcprtt                  0
# synack                  0
# ackdat                  0
# ...

# %% [markdown]
# ### 2. Filling missing values with most occurring values

# %%
df_2 = df1

# %%
df_2.isna().sum()
# Out:
# srcip                   0
# sport                   0
# dstip                   0
# dsport                  0
# proto                   0
# state                   0
# dur                     0
# sbytes                  0
# dbytes                  0
# sttl                    0
# dttl                    0
# sloss                   0
# dloss                   0
# service                 0
# Sload                   0
# Dload                   0
# Spkts                   0
# Dpkts                   0
# swin                    0
# dwin                    0
# stcpb                   0
# dtcpb                   0
# smeansz                 0
# dmeansz                 0
# trans_depth             0
# res_bdy_len             0
# Sjit                    0
# Djit                    0
# Stime                   0
# Ltime                   0
# Sintpkt                 0
# Dintpkt                 0
# tcprtt                  0
# synack                  0
# ackdat                  0
# ...

# %%
df_2["attack_cat"].value_counts()
# Out:
#  Fuzzers          1713
# Exploits          1705
# Reconnaissance     648
# DoS                280
# Generic            233
# Shellcode           84
# Backdoors           24
# Worms                8
# Name: attack_cat, dtype: int64

# %%
df_2 = df_2.apply(lambda x: x.fillna(x.value_counts().index[0]))

# %%
df_2["attack_cat"].isna().sum()
# Out:
# 0

# %%
# results in bias

df_2["attack_cat"].value_counts()
# Out:
#  Fuzzers          62553
# Exploits           1705
# Reconnaissance      648
# DoS                 280
# Generic             233
# Shellcode            84
# Backdoors            24
# Worms                 8
# Name: attack_cat, dtype: int64

# %% [markdown]
# ### 3. Using sklearn Imputers to fill missing values

# %% [markdown]
# #### a. Simple Imputer

# %%
df_3_a = df1

# %%
df_3_a.shape
# Out:
# (65535, 49)

# %%
df_3_a["attack_cat"].value_counts()
# Out:
#  Fuzzers          1713
# Exploits          1705
# Reconnaissance     648
# DoS                280
# Generic            233
# Shellcode           84
# Backdoors           24
# Worms                8
# Name: attack_cat, dtype: int64

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder 

imputer_simple = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imputer_simple = imputer_simple.fit(df_3_a[["attack_cat"]])

# %%
df_3_a["attack_cat"] = imputer_simple.transform(df_3_a[["attack_cat"]])

# %%
df_3_a["attack_cat"].isna().sum()
# Out:
# 0

# %% [markdown]
# #### b. Iterative Imputer

# %%
df_3_b = df1

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.preprocessing import LabelEncoder 

le = LabelEncoder()

  
df_3_b = df_3_b.apply(lambda col: le.fit_transform(col.astype(str)), axis=0, result_type='expand')

df_3_b = df_3_b.apply(lambda series: pd.Series(
        LabelEncoder().fit_transform(series[series.notnull()]),
        index=series[series.notnull()].index
    ))

imputer_iterative = IterativeImputer(random_state=0)
imputer_iterative = imputer_iterative.fit(df_3_b[["attack_cat"]])
# IterativeImputer(random_state=0)

df_3_b[["attack_cat"]] = imputer_iterative.transform(df_3_b[["attack_cat"]])

# %%
df_3_b["attack_cat"].isna().sum()
# Out:
# 0

# %%
df_3_b["attack_cat"].value_counts()
# Out:
# 0.0    62553
# 3.0     1705
# 5.0      648
# 2.0      280
# 4.0      233
# 6.0       84
# 1.0       24
# 7.0        8
# Name: attack_cat, dtype: int64

# %% [markdown]
# #### c. Knn Imputer

# %%
df_3_c = df1

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import MinMaxScaler

mm = MinMaxScaler()

def find_category_mappings(df, variable):
    return {k: i for i, k in enumerate(df[variable].dropna().unique(), 0)}

def integer_encode(df , variable, ordinal_mapping):
    df[variable] = df[variable].map(ordinal_mapping)

mappin = dict()
def imputation(df1 , cols):
    df = df1.copy()
    #Encoding dict &amp; Removing nan    
    #mappin = dict()
    for variable in cols:
        mappings = find_category_mappings(df, variable)
        mappin[variable] = mappings

    #Apply mapping
    for variable in cols:
        integer_encode(df, variable, mappin[variable])  

    #Minmaxscaler and KNN imputation 
    sca = mm.fit_transform(df)
    knn_imputer = KNNImputer()
    knn = knn_imputer.fit_transform(sca)
    df.iloc[:,:] = mm.inverse_transform(knn)
    for i in df.columns : 
        df[i] = round(df[i]).astype('int')

    #Inverse transform
    for i in cols:
        inv_map = {v: k for k, v in mappin[i].items()}
        df[i] = df[i].map(inv_map)
    return df

# %%
#Imputation

df_3_c = df_3_c.fillna("")

df_3_c = df_3_c.apply(lambda col: le.fit_transform(col.astype(str)), axis=0, result_type='expand')

df_3_c=imputation(df_3_c,["attack_cat"])
# Out:
# <ipython-input-40-4a4c9cf68690>:29: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:,:] = mm.inverse_transform(knn)

# %%
df_3_c["attack_cat"].isna().sum()
# Out:
# 0

# %%
df_3_c["attack_cat"].value_counts()
# Out:
# 0    62553
# 3     1705
# 5      648
# 2      280
# 4      233
# 6       84
# 1       24
# 7        8
# Name: attack_cat, dtype: int64

# %% [markdown]
# ##### Out of all the above approaches, Dropping of rows and columns is one good method for handling these missing values. Also here are some following:
# 1. Other methods, replacing with most_frequent value and Imputers create a bias.
# 2. As the dataset is very large, hence some of the rows can be dropped to avoid this bias.

# %% [markdown]
# ### Processing other datasets

# %%
df_2 = df2

# %%
df_2["attack_cat"].value_counts()
# Out:
# Generic             27883
# Exploits            11103
#  Fuzzers             4668
# DoS                  4637
#  Reconnaissance      3116
# Analysis              608
# Backdoor              370
#  Shellcode            324
# Worms                  40
# Name: attack_cat, dtype: int64

# %%
df_2["attack_cat"]

# %%
df_2.isna().sum()
# Out:
# srcip                    0
# sport                    0
# dstip                    0
# dsport                   0
# proto                    0
# state                    0
# dur                      0
# sbytes                   0
# dbytes                   0
# sttl                     0
# dttl                     0
# sloss                    0
# dloss                    0
# service                  0
# Sload                    0
# Dload                    0
# Spkts                    0
# Dpkts                    0
# swin                     0
# dwin                     0
# stcpb                    0
# dtcpb                    0
# smeansz                  0
# dmeansz                  0
# trans_depth              0
# res_bdy_len              0
# Sjit                     0
# Djit                     0
# Stime                    0
# Ltime                    0
# Sintpkt                  0
# Dintpkt                  0
# tcprtt                   0
# synack                   0
# ...

# %%
df_2.shape
# Out:
# (700000, 49)

# %%
df_2.corr()
# Out:
# <ipython-input-47-2f9b2efe1c6b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_2.corr()
#                      sport       dur    sbytes    dbytes      sttl      dttl  \
# sport             1.000000 -0.056288  0.004097  0.015536 -0.134850  0.087054
# dur              -0.056288  1.000000  0.122406  0.326494 -0.007120  0.035189
# sbytes            0.004097  0.122406  1.000000  0.051206 -0.002989  0.061545
# dbytes            0.015536  0.326494  0.051206  1.000000 -0.072862 -0.000744
# sttl             -0.134850 -0.007120 -0.002989 -0.072862  1.000000  0.208579
# dttl              0.087054  0.035189  0.061545 -0.000744  0.208579  1.000000
# sloss             0.018474  0.159184  0.944580  0.123297 -0.055492  0.064130
# dloss             0.020602  0.330354  0.056093  0.991023 -0.092604  0.000951
# ...

# %%
# As ct_flw_http_mthd, is_ftp_login columns have very very less correlation with final result they can be dropped 

df_2 = df_2.drop(['ct_flw_http_mthd','is_ftp_login' ], axis = 1)

# %%
df_2.shape
# Out:
# (700000, 47)

# %%
# deleting rows with missing values

df_2 = df_2.dropna()

# %%
df_2.shape
# Out:
# (52749, 47)

# %%
df_2["attack_cat"].isna().sum()
# Out:
# 0

# %%
df_2.isna().sum()
# Out:
# srcip               0
# sport               0
# dstip               0
# dsport              0
# proto               0
# state               0
# dur                 0
# sbytes              0
# dbytes              0
# sttl                0
# dttl                0
# sloss               0
# dloss               0
# service             0
# Sload               0
# Dload               0
# Spkts               0
# Dpkts               0
# swin                0
# dwin                0
# stcpb               0
# dtcpb               0
# smeansz             0
# dmeansz             0
# trans_depth         0
# res_bdy_len         0
# Sjit                0
# Djit                0
# Stime               0
# Ltime               0
# Sintpkt             0
# Dintpkt             0
# tcprtt              0
# synack              0
# ackdat              0
# is_sm_ips_ports     0
# ct_state_ttl        0
# ct_ftp_cmd          0
# ct_srv_src          0
# ct_srv_dst          0
# ct_dst_ltm          0
# ...

# %%
df_2["Label"].value_counts()
# Out:
# 1    52749
# Name: Label, dtype: int64

# %%
df_2["attack_cat"].value_counts()
# Out:
# Generic             27883
# Exploits            11103
#  Fuzzers             4668
# DoS                  4637
#  Reconnaissance      3116
# Analysis              608
# Backdoor              370
#  Shellcode            324
# Worms                  40
# Name: attack_cat, dtype: int64

# %%
# Third dataset

# %%
df_3 = df3

# %%
df_3.shape
# Out:
# (700000, 49)

# %%
df_3.corr()
# Out:
# <ipython-input-56-65f7080f83c3>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_3.corr()
#                      sport       dur    sbytes    dbytes      sttl      dttl  \
# sport             1.000000 -0.042248  0.009942  0.034807 -0.179862  0.138285
# dur              -0.042248  1.000000  0.150769  0.308285 -0.010121  0.073593
# sbytes            0.009942  0.150769  1.000000  0.037688 -0.012740  0.069939
# dbytes            0.034807  0.308285  0.037688  1.000000 -0.116664  0.023447
# sttl             -0.179862 -0.010121 -0.012740 -0.116664  1.000000  0.055396
# dttl              0.138285  0.073593  0.069939  0.023447  0.055396  1.000000
# sloss             0.031485  0.173404  0.970615  0.098635 -0.073487  0.087544
# dloss             0.044599  0.309935  0.040248  0.992173 -0.145968  0.032082
# ...

# %%
df_3.isna().sum()
# Out:
# srcip                    0
# sport                    0
# dstip                    0
# dsport                   0
# proto                    0
# state                    0
# dur                      0
# sbytes                   0
# dbytes                   0
# sttl                     0
# dttl                     0
# sloss                    0
# dloss                    0
# service                  0
# Sload                    0
# Dload                    0
# Spkts                    0
# Dpkts                    0
# swin                     0
# dwin                     0
# stcpb                    0
# dtcpb                    0
# smeansz                  0
# dmeansz                  0
# trans_depth              0
# res_bdy_len              0
# Sjit                     0
# Djit                     0
# Stime                    0
# Ltime                    0
# Sintpkt                  0
# Dintpkt                  0
# tcprtt                   0
# synack                   0
# ...

# %%
# As ct_flw_http_mthd, is_ftp_login columns have very very less correlation with final result they can be dropped 

df_3 = df_3.drop(['ct_flw_http_mthd','is_ftp_login' ], axis = 1)

# %%
df_3.shape
# Out:
# (700000, 47)

# %%
df_3.isna().sum()
# Out:
# srcip                    0
# sport                    0
# dstip                    0
# dsport                   0
# proto                    0
# state                    0
# dur                      0
# sbytes                   0
# dbytes                   0
# sttl                     0
# dttl                     0
# sloss                    0
# dloss                    0
# service                  0
# Sload                    0
# Dload                    0
# Spkts                    0
# Dpkts                    0
# swin                     0
# dwin                     0
# stcpb                    0
# dtcpb                    0
# smeansz                  0
# dmeansz                  0
# trans_depth              0
# res_bdy_len              0
# Sjit                     0
# Djit                     0
# Stime                    0
# Ltime                    0
# Sintpkt                  0
# Dintpkt                  0
# tcprtt                   0
# synack                   0
# ...

# %%
# dropping rows with missing values

df_3 = df_3.dropna()

# %%
df_3.shape
# Out:
# (157425, 47)

# %%
df_3["attack_cat"].value_counts()
# Out:
# Generic           118198
# Exploits           16574
# Fuzzers             9137
# DoS                 5642
# Reconnaissance      5582
# Analysis             873
# Backdoor             759
# Shellcode            593
# Worms                 67
# Name: attack_cat, dtype: int64

# %%
df_3["attack_cat"].isna().sum()
# Out:
# 0

# %%
# fourth dataset

# %%
df_4 = df4

# %%
df_4.shape
# Out:
# (440043, 49)

# %%
df_4.isna().sum()
# Out:
# srcip                    0
# sport                    0
# dstip                    0
# dsport                   0
# proto                    0
# state                    0
# dur                      0
# sbytes                   0
# dbytes                   0
# sttl                     0
# dttl                     0
# sloss                    0
# dloss                    0
# service                  0
# Sload                    0
# Dload                    0
# Spkts                    0
# Dpkts                    0
# swin                     0
# dwin                     0
# stcpb                    0
# dtcpb                    0
# smeansz                  0
# dmeansz                  0
# trans_depth              0
# res_bdy_len              0
# Sjit                     0
# Djit                     0
# Stime                    0
# Ltime                    0
# Sintpkt                  0
# Dintpkt                  0
# tcprtt                   0
# synack                   0
# ...

# %%
# As ct_flw_http_mthd, is_ftp_login columns have very very less correlation with final result they can be dropped 

df_4 = df_4.drop(['ct_flw_http_mthd','is_ftp_login' ], axis = 1)

# %%
df_4.shape
# Out:
# (440043, 47)

# %%
# dropping having missing values

df_4 = df_4.dropna()

# %%
df_4.shape
# Out:
# (88894, 47)

# %%
df_3["attack_cat"].value_counts()
# Out:
# Generic           118198
# Exploits           16574
# Fuzzers             9137
# DoS                 5642
# Reconnaissance      5582
# Analysis             873
# Backdoor             759
# Shellcode            593
# Worms                 67
# Name: attack_cat, dtype: int64

# %%
df_4["attack_cat"].isna().sum()
# Out:
# 0

# %%
df_1["attack_cat"].value_counts()
# Out:
#  Fuzzers          1713
# Exploits          1705
# Reconnaissance     648
# DoS                280
# Generic            233
# Shellcode           84
# Backdoors           24
# Worms                8
# Name: attack_cat, dtype: int64

# %%
df_2["attack_cat"].value_counts()
# Out:
# Generic             27883
# Exploits            11103
#  Fuzzers             4668
# DoS                  4637
#  Reconnaissance      3116
# Analysis              608
# Backdoor              370
#  Shellcode            324
# Worms                  40
# Name: attack_cat, dtype: int64

# %%
df_3["attack_cat"].value_counts()
# Out:
# Generic             118198
# Exploits             16574
#  Fuzzers              9137
# DoS                   5642
#  Reconnaissance       5582
# Analysis               873
# Backdoor               759
#  Shellcode             593
# Worms                   67
# Name: attack_cat, dtype: int64

# %%
df_4["attack_cat"].value_counts()
# Out:
# Generic             61878
# Exploits            11439
#  Fuzzers             5390
# DoS                  4907
#  Reconnaissance      3530
# Analysis              670
# Backdoor              666
#  Shellcode            371
# Worms                  43
# Name: attack_cat, dtype: int64

# %%
df_1["attack_cat"] = df_1["attack_cat"].str.strip() 
df_2["attack_cat"] = df_2["attack_cat"].str.strip() 
df_3["attack_cat"] = df_3["attack_cat"].str.strip() 
df_4["attack_cat"] = df_4["attack_cat"].str.strip()

# %%
df_12 = pd.concat([df_1, df_2])
df_12["attack_cat"].value_counts()
# Out:
# Generic           28116
# Exploits          12808
# Fuzzers            6381
# DoS                4917
# Reconnaissance     3764
# Analysis            608
# Shellcode           408
# Backdoor            370
# Worms                48
# Backdoors            24
# Name: attack_cat, dtype: int64

# %%
df_23 = pd.concat([df_2, df_3])
df_23["attack_cat"].value_counts()
# Out:
# Generic           146081
# Exploits           27677
# Fuzzers            13805
# DoS                10279
# Reconnaissance      8698
# Analysis            1481
# Backdoor            1129
# Shellcode            917
# Worms                107
# Name: attack_cat, dtype: int64

# %%
df_34 = pd.concat([df_3, df_4])
df_34["attack_cat"].value_counts()
# Out:
# Generic           180076
# Exploits           28013
# Fuzzers            14527
# DoS                10549
# Reconnaissance      9112
# Analysis            1543
# Backdoor            1425
# Shellcode            964
# Worms                110
# Name: attack_cat, dtype: int64

# %%
df_13 = pd.concat([df_1, df_3])
df_13["attack_cat"].value_counts()
# Out:
# Generic           118431
# Exploits           18279
# Fuzzers            10850
# Reconnaissance      6230
# DoS                 5922
# Analysis             873
# Backdoor             759
# Shellcode            677
# Worms                 75
# Backdoors             24
# Name: attack_cat, dtype: int64

# %%
df_14 = pd.concat([df_1, df_4])
df_14["attack_cat"].value_counts()
# Out:
# Generic           62111
# Exploits          13144
# Fuzzers            7103
# DoS                5187
# Reconnaissance     4178
# Analysis            670
# Backdoor            666
# Shellcode           455
# Worms                51
# Backdoors            24
# Name: attack_cat, dtype: int64

# %%
df_24 = pd.concat([df_2, df_4])
df_24["attack_cat"].value_counts()
# Out:
# Generic           89761
# Exploits          22542
# Fuzzers           10058
# DoS                9544
# Reconnaissance     6646
# Analysis           1278
# Backdoor           1036
# Shellcode           695
# Worms                83
# Name: attack_cat, dtype: int64

# %%
df_34.corr()
# Out:
# <ipython-input-97-51bcda0599e4>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_34.corr()
#                      sport       dur    sbytes    dbytes      sttl      dttl  \
# sport             1.000000 -0.042264  0.012642  0.016759 -0.115675  0.208836
# dur              -0.042264  1.000000  0.217511  0.154847 -0.079176  0.110883
# sbytes            0.012642  0.217511  1.000000  0.009820 -0.071294  0.077754
# dbytes            0.016759  0.154847  0.009820  1.000000 -0.133255  0.086225
# sttl             -0.115675 -0.079176 -0.071294 -0.133255  1.000000 -0.579869
# dttl              0.208836  0.110883  0.077754  0.086225 -0.579869  1.000000
# sloss             0.018121  0.216342  0.997285  0.008397 -0.085358  0.097270
# dloss             0.021202  0.155840  0.006733  0.999240 -0.154202  0.107701
# ...

# %% [markdown]
# ##### Out of above combinations, the combinations of dataset 1 & 2 is better and less biased

# %%
df_2 = df2

# %%
df_2 = df_2.drop(['ct_flw_http_mthd', 'is_ftp_login'], axis=1)

# %%
df_2.head()
# Out:
#         srcip  sport          dstip dsport proto state       dur  sbytes  \
# 0  59.166.0.0   7832  149.171.126.3   5607   tcp   FIN  0.144951    5174
# 1  59.166.0.8  11397  149.171.126.6     21   tcp   FIN  0.116107    2934
# 2  59.166.0.0   3804  149.171.126.3     53   udp   CON  0.000986     146
# 3  59.166.0.8  14339  149.171.126.6  14724   tcp   FIN  0.038480    8928
# 4  59.166.0.8  39094  149.171.126.3     53   udp   CON  0.001026     130
#
#    dbytes  sttl  ...  ct_ftp_cmd  ct_srv_src  ct_srv_dst ct_dst_ltm  \
# 0   91072    31  ...           0          13          13          6
# 1    3742    31  ...           1           1           2          7
# 2     178    31  ...           0          13          13          6
# 3     320    31  ...           0           8          20          7
# 4     162    31  ...           0           8          13          6
#
#    ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# ...

# %%
df_2.shape
# Out:
# (700000, 47)

# %%
df_missing = df_2[df_2.isnull().any(axis=1)]

# %%
df_missing.head()
# Out:
#         srcip  sport          dstip dsport proto state       dur  sbytes  \
# 0  59.166.0.0   7832  149.171.126.3   5607   tcp   FIN  0.144951    5174
# 1  59.166.0.8  11397  149.171.126.6     21   tcp   FIN  0.116107    2934
# 2  59.166.0.0   3804  149.171.126.3     53   udp   CON  0.000986     146
# 3  59.166.0.8  14339  149.171.126.6  14724   tcp   FIN  0.038480    8928
# 4  59.166.0.8  39094  149.171.126.3     53   udp   CON  0.001026     130
#
#    dbytes  sttl  ...  ct_ftp_cmd  ct_srv_src  ct_srv_dst ct_dst_ltm  \
# 0   91072    31  ...           0          13          13          6
# 1    3742    31  ...           1           1           2          7
# 2     178    31  ...           0          13          13          6
# 3     320    31  ...           0           8          20          7
# 4     162    31  ...           0           8          13          6
#
#    ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# ...

# %%
df_missing.shape
# Out:
# (647251, 47)

# %% [markdown]
# ##### randomly selecting rows where there is no intrusion

# %%
df_random = df_missing.sample(n=40000)

# %%
df_filled = df_2.dropna()

# %%
df_filled.shape
# Out:
# (52749, 47)

# %%
df_merged = pd.concat([df_random, df_filled])

# %%
df_merged.shape
# Out:
# (92749, 47)

# %% [markdown]
# ##### Renaming the category as 'Normal' where there is no intrusion

# %%
df_merged = df_merged.fillna('Normal')

# %%
df_merged.isna().sum()
# Out:
# srcip               0
# sport               0
# dstip               0
# dsport              0
# proto               0
# state               0
# dur                 0
# sbytes              0
# dbytes              0
# sttl                0
# dttl                0
# sloss               0
# dloss               0
# service             0
# Sload               0
# Dload               0
# Spkts               0
# Dpkts               0
# swin                0
# dwin                0
# stcpb               0
# dtcpb               0
# smeansz             0
# dmeansz             0
# trans_depth         0
# res_bdy_len         0
# Sjit                0
# Djit                0
# Stime               0
# Ltime               0
# Sintpkt             0
# Dintpkt             0
# tcprtt              0
# synack              0
# ackdat              0
# is_sm_ips_ports     0
# ct_state_ttl        0
# ct_ftp_cmd          0
# ct_srv_src          0
# ct_srv_dst          0
# ct_dst_ltm          0
# ...

# %%
df_merged["attack_cat"].value_counts()
# Out:
# Normal              40000
# Generic             27883
# Exploits            11103
#  Fuzzers             4668
# DoS                  4637
#  Reconnaissance      3116
# Analysis              608
# Backdoor              370
#  Shellcode            324
# Worms                  40
# Name: attack_cat, dtype: int64

# %%
df_merged["Label"].value_counts()
# Out:
# 1    52749
# 0    40000
# Name: Label, dtype: int64

# %%
df_merged.to_csv("merged_pre_processed.csv")

# %% [markdown]
# ##### In this notebook all four datasets are used , pre-processed for handling missing values. Combination of datasets 1 & 2 is selected because it has better distribution of attack categories and is very less biased. For 'Normal' type or where there 'No attack', these rows(40,000) are selected randomly from second dataset. This dataFrame is now saved into a new csv file and will be pre-processed further
